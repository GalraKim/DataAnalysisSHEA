# %%
# !pip install selenium

# %%
# !pip install webdriver_manager

# %%
from selenium import webdriver
from lib2to3.pgen2 import driver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC

# %%
service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
try:
  driver.get("https://www.nbcomputers.ru/catalog/noutbuki/")
  driver.implicitly_wait(10)

  actions = ActionChains(driver)
  actions.move_to_element(driver.find_element(By.CSS_SELECTOR, '[aria-label="Показать ещё больше товаров"]'))
  actions.perform()
  wait = WebDriverWait(driver, timeout=10)
  
  while True:
    
    wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, '[aria-label="Показать ещё больше товаров"]'))).click()
    wait = WebDriverWait(driver, timeout=3)

except Exception as ex:
  print(f'Error: {ex}')

html = driver.page_source
driver.quit()
# Out:
# [WDM] - Downloading: 100%|██████████| 6.79M/6.79M [01:37<00:00, 73.0kB/s]
# Error: Message:
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00686643]
# 	(No symbol) [0x0061BE21]
# 	(No symbol) [0x0051DA9D]
# 	(No symbol) [0x00551342]
# 	(No symbol) [0x0055147B]
# 	(No symbol) [0x00588DC2]
# 	(No symbol) [0x0056FDC4]
# 	(No symbol) [0x00586B09]
# 	(No symbol) [0x0056FB76]
# 	(No symbol) [0x005449C1]
# 	(No symbol) [0x00545E5D]
# 	GetHandleVerifier [0x008FA142+2497106]
# 	GetHandleVerifier [0x009285D3+2686691]
# 	GetHandleVerifier [0x0092BB9C+2700460]
# 	GetHandleVerifier [0x00733B10+635936]
# 	(No symbol) [0x00624A1F]
# 	(No symbol) [0x0062A418]
# 	(No symbol) [0x0062A505]
# 	(No symbol) [0x0063508B]
# 	BaseThreadInitThunk [0x774200F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77877BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77877B8E+238]

# %%
import requests
from requests.exceptions import HTTPError
from bs4 import BeautifulSoup
import csv

# %%
try:
    final_result = []
    soup = BeautifulSoup(html, 'html5lib')
    
    divs = soup.select_one("div.sc-26679455-1.gGStFX")
    
    for div in divs:
      name = div.select_one("h2.sc-d9406361-0.hdfxoN").text
      target = div.select_one("span.sc-96470d6e-2.jsNMaY").text
      code = div.select_one("p.sc-d9406361-0.cCQtSh").text[4:]
      notebook = {
        "Name": name, 
        "Target": target,
        "Code": code
      }
      final_result.append(notebook)


except HTTPError as ht:
  print(f"ERROR: {ht}")
except Exception as ex:
  print(f"ERROR: {ex}")
print(final_result)
# Out:
# [{'Name': 'Ноутбук MSI Katana GF66 11UC-1225RU 15.6"/8/SSD 512/черный', 'Target': '79\xa0990\xa0₽', 'Code': ' 110688'}, {'Name': 'Ноутбук Lenovo IdeaPad 3 14ALC6 14"/12/SSD 512/синий', 'Target': '67\xa0990\xa0₽', 'Code': ' 108521'}, {'Name': 'Ноутбук Asus ROG Zephyrus M16 GU603
avilion 15-eg0134ur 15.6"/16/SSD 512/серебристый', 'Target': '71\xa0990\xa0₽', 'Code': ' 106859'}, {'Name': 'Ноутбук HP Envy 15-ep1031ur 15.6"/16/SSD 1024/серебристый', 'Target': '159\xa0990\xa0₽', 'Code': ' 113203'}, {'Name': 'Ноутбук MSI Stealth GS66 12UGS-212RU 15.6"/32/SSD 1024/черный', 'Target': '196\xa0990\xa0₽', 'Code': ' 109809'}, {'Name': 'Ноутбук Acer Predator Triton 500 SE  PT516-51s-757L 16"/16/SSD 1024/серый', 'Target': '149\xa0990\xa0₽', 'Code': ' 110774'}, {'Name': 'Ноутбук MSI Pulse GL76 12UEK-088XRU 17.3"/16/SSD 512/серый', 'Target': '113\xa0990\xa0₽', 'Code': ' 109769'}, {'Name': 'Ультрабук Asus ZenBook 13 UX325EA-KG763 13.3"/16/SSD 512/лиловый', 'Target': '84\xa0990\xa0₽', 'Code': ' 110857'}, {'Name': 'Ноутбук Asus ROG Zephyrus M16 GU603HE-K8057R 16"/16/SSD 1024/черный', 'Target': '169\xa0990\xa0₽', 'Code': ' 112246'}, {'Name': 'Ноутбук Asus TUF Gaming Dash F15 FX516PC-HN558 15.6"/8/SSD 512/серый', 'Target': '78\xa0990\xa0₽', 'Code': ' 114774'}, {'Name': 'Ноутбук Asus ROG Strix G15 G513RM-HQ164W 15.6"/16/SSD 1024/серый', 'Target': '189\xa0990\xa0₽', 'Code': ' 109544'}, {'Name': 'Ноутбук Xiaomi RedmiBook 15 X43260 15.6"/8/SSD 256/серый', 'Target': '34\xa0990\xa0₽', 'Code': ' 117096'}, {'Name': 'Ноутбук Asus TUF Gaming F15 FX506LHB-HN323W 15.6"/8/SSD 512/черный', 'Target': '69\xa0990\xa0₽', 'Code': ' 116639'}, {'Name': 'Ноутбук Xiaomi RedmiBook 15 X44450 15.6"/8/SSD 512/серый', 'Target': '44\xa0990\xa0₽', 'Code': ' 117097'}, {'Name': 'Ноутбук Asus VivoBook Pro 15 K6500Z 15.6"/16/SSD 512/серебристый', 'Target': '108\xa0990\xa0₽', 'Code': ' 117438'}, {'Name': 'Ноутбук Machenike S15 15.6"/16/SSD 512/черный', 'Target': '101\xa0990\xa0₽', 'Code': ' 116888'}, {'Name': 'Ноутбук Asus ROG Zephyrus M16 GU603ZM-K8078W 16"/16/SSD 512/черный', 'Target': '179\xa0990\xa0₽', ...

# %%
with open("task2_2.csv", "w",  encoding="utf-8") as f:
  writer = csv.DictWriter(f, final_result[0].keys())
  writer.writeheader()
  for r in final_result:
    writer.writerow(r)
